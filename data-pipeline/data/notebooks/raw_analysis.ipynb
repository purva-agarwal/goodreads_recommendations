# %%
# ---
# Title: Goodreads BigQuery Data Exploration
# Description: Inspect raw BigQuery data to understand schema, null patterns, and data distributions
# ---

from google.cloud import bigquery
import os

# -------------------------------------------------------------------
# 1. Connect to BigQuery
# -------------------------------------------------------------------
if os.path.exists("gcp_credentials.json"):
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "gcp_credentials.json"

client = bigquery.Client(project="recommendation-system-475301")
print("✅ Connected to BigQuery!")
# Out:
# ✅ Connected to BigQuery!

# %%
# -------------------------------------------------------------------
# 2. Query sample data
# -------------------------------------------------------------------
QUERY = """
SELECT
  book_id,
  title,
  authors,
  average_rating,
  ratings_count,
  popular_shelves,
  description
FROM `recommendation-system-475301.books.goodreads_books_mystery_thriller_crime`
WHERE title IS NOT NULL
LIMIT 10000
"""

df = client.query(QUERY).to_dataframe()
print(f"✅ Retrieved {len(df)} rows and {len(df.columns)} columns")
df.head()
# Out:
# ✅ Retrieved 10000 rows and 7 columns
#     book_id                                      title  \
# 0  25744824                      Pieces Of One, Part 1
# 1  36225808           Preacher Man (DI Ted Darling #8)
# 2  20339311                          Track Down Africa
# 3  26094450     The Old House (Haunted Series Book 16)
# 4  26249939  Never Screw Up (Stockholm Noir Trilogy 2)
#
#                                  authors  average_rating  ratings_count  \
# 0   [{'role': '', 'author_id': 8635673}]            4.65             14
# 1  [{'role': '', 'author_id': 13476159}]            4.48            226
# 2   [{'role': '', 'author_id': 7709001}]            3.38             48
# 3   [{'role': '', 'author_id': 5439921}]            4.56            178
# 4    [{'role': '', 'author_id': 824407}]            3.30              3
#
#                                      popular_shelves  \
# 0  [{'name': 'to-read', 'count': 283}, {'name': '...
# 1  [{'name': 'currently-reading', 'count': 30}, {...
# 2  [{'name': 'to-read', 'count': 50}, {'name': 'c...
# 3  [{'name': 'to-read', 'count': 26}, {'name': 'c...
# 4  [{'name': 'to-read', 'count': 238}, {'name': '...
#
#                                          description
# 0  Two men want me and I want them. Simple, right...
# 1  A teenager is found naked and wandering in a l...
# 2
# 3
# 4  Jens Lapidus debutroman Snabba cash ar en av 2...

# %%
# -------------------------------------------------------------------
# 3. Quick info and summary
# -------------------------------------------------------------------
print("\n📊 Data Info:")
df.info()

print("\n🧮 Null Values:")
print(df.isna().sum())

print("\n📈 Numeric summary:")
display(df.describe())

print("\n📋 Column overview (robust):")
for col in df.columns:
    s = df[col]
    dtype = str(s.dtype)
    na = s.isna().sum()
    missing_pct = s.isna().mean() * 100

    # Handle unhashable types safely
    try:
        unique = s.nunique(dropna=True)
    except TypeError:
        unique = "unhashable"  # e.g., lists/dicts inside column

    print(f"{col:<25} | dtype: {dtype:15} | missing: {missing_pct:5.1f}% | uniques: {unique}")
# Out:
# 📊 Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   book_id          10000 non-null  Int64
#  1   title            10000 non-null  object
#  2   authors          10000 non-null  object
#  3   average_rating   10000 non-null  float64
#  4   ratings_count    10000 non-null  Int64
#  5   popular_shelves  10000 non-null  object
#  6   description      10000 non-null  object
# dtypes: Int64(2), float64(1), object(4)
# memory usage: 566.5+ KB
#
# 🧮 Null Values:
# book_id            0
# title              0
# authors            0
# average_rating     0
# ratings_count      0
# popular_shelves    0
# description        0
# dtype: int64
#
# 📈 Numeric summary:
#               book_id  average_rating  ratings_count
# count         10000.0    10000.000000        10000.0
# mean    18248082.6496        3.877463       415.7404
# std    11088729.60147        0.344889    2336.187652
# min             205.0        1.000000            0.0
# 25%         8266747.5        3.680000           14.0
# 50%        19980689.5        3.880000           50.0
# 75%       27222382.75        4.090000         177.25
# max        36469871.0        5.000000        81270.0
# 📋 Column overview (robust):
# book_id                   | dtype: Int64           | missing:   0.0% | uniques: 10000
# title                     | dtype: object          | missing:   0.0% | uniques: 9599
# authors                   | dtype: object          | missing:   0.0% | uniques: unhashable
# average_rating            | dtype: float64         | missing:   0.0% | uniques: 235
# ratings_count             | dtype: Int64           | missing:   0.0% | uniques: 1353
# popular_shelves           | dtype: object          | missing:   0.0% | uniques: unhashable
# description               | dtype: object          | missing:   0.0% | uniques: 7367

# %%
# -------------------------------------------------------------------
# 4. Inspect example rows and JSON-like fields
# -------------------------------------------------------------------
print("\n🧩 Example rows:")
display(df.sample(5, random_state=42))

print("\n🔍 Example 'authors' field values:")
for val in df["authors"].dropna().head(5):
    print(val)

print("\n📚 Example 'popular_shelves' values:")
for val in df["popular_shelves"].dropna().head(3):
    print(val)
# Out:
# 🧩 Example rows:
#        book_id                                              title  \
# 6252  18964799  3 for Murder Box Set (Jim Richards Murder Nove...
# 4684    927525                            The Stars' Tennis Balls
# 1731  34430429    Pugs, Thugs, and Murder (Pet Shop Mysteries #6)
# 4742  31843828  A Deadly Affection (Dr. Genevieve Summerford M...
# 4521   1665778                               Vanish in an Instant
#
#                                     authors  average_rating  ratings_count  \
# 6252   [{'role': '', 'author_id': 3462789}]            3.91             22
# 4684     [{'role': '', 'author_id': 10917}]            3.79            264
# 1731  [{'role': '', 'author_id': 16214668}]            4.49             71
# 4742   [{'role': '', 'author_id': 5446103}]            3.80            135
# 4521      [{'role': '', 'author_id': 8636}]            3.78              6
#
#                                         popular_shelves  \
# 6252  [{'name': 'to-read', 'count': 47}, {'name': 'c...
# 4684  [{'name': 'to-read', 'count': 897}, {'name': '...
# 1731  [{'name': 'to-read', 'count': 22}, {'name': 'c...
# 4742  [{'name': 'to-read', 'count': 3390}, {'name': ...
# 4521  [{'name': 'to-read', 'count': 62}, {'name': 'm...
#
#                                             description
# 6252
# 4684  10 hrs\nFor Ned, 1980 seems a blissful year. H...
# 1731  Pet shop owner and hesitant novice investigato...
# 4742  "Do no harm" is easier said than done...\nDr. ...
# 4521
# 🔍 Example 'authors' field values:
# [{'role': '', 'author_id': 8635673}]
# [{'role': '', 'author_id': 13476159}]
# [{'role': '', 'author_id': 7709001}]
# [{'role': '', 'author_id': 5439921}]
# [{'role': '', 'author_id': 824407}]
#
# 📚 Example 'popular_shelves' values:
# [{'name': 'to-read', 'count': 283} {'name': 'dark', 'count': 5}
#  {'name': 'kindle', 'count': 4} {'name': 'freebie', 'count': 2}
#  {'name': 'contemporary-romance', 'count': 2}
#  {'name': 'currently-reading', 'count': 2} {'name': 'romance', 'count': 2}
#  {'name': 'want-to-read', 'count': 2}
#  {'name': 'kindle-unlimited', 'count': 1}
#  {'name': 'previewed-not-for-me', 'count': 1}
#  {'name': 'owned-kindle', 'count': 1}
#  {'name': 'erotic-suspense', 'count': 1}
#  {'name': 'unread-on-kindle', 'count': 1}
#  {'name': 'coming-soon', 'count': 1}
#  {'name': 'owned-pending-kindle-free-ebook', 'count': 1}
#  {'name': '5', 'count': 1} {'name': 'complete-series', 'count': 1}
#  {'name': 'd-t-h', 'count': 1}
#  {'name': 'ahh-bliss-of-mentally-ill', 'count': 1}
#  {'name': 'a-4-plus-star-avg-review', 'count': 1}
#  {'name': 'books', 'count': 1} {'name': '1-amazon', 'count': 1}
#  {'name': '01-tbr-on-kindle', 'count': 1} {'name': 'ts', 'count': 1}
#  {'name': 'series', 'count': 1} {'name': 'others', 'count': 1}
#  {'name': 'hot', 'count': 1}
#  {'name': 'excellent-supporting-cast', 'count': 1}
#  {'name': 'engaging', 'count': 1}
#  {'name': 'contains-apprehension', 'count': 1}
#  {'name': 'arc-received-publisher-send', 'count': 1}
#  {'name': 'kindle-2', 'count': 1}
#  {'name': 'kindle-need-to-reads', 'count': 1}
#  {'name': 'kindle-unlimited-tbr', 'count': 1}
#  {'name': '2015-releases', 'count': 1} {'name': 'owned-books', 'count': 1}
#  {'name': 'thriller', 'count': 1} {'name': 'taboo', 'count': 1}
#  {'name': 'suspense', 'count': 1} {'name': 'unread-kindle', 'count': 1}
#  {'name': 'dark-erotica', 'count': 1} {'name': '100-200pg', 'count': 1}
#  {'name': 'mafia-crime-thriller', 'count': 1}
#  {'name': 'romance-suspense', 'count': 1}
#  {'name': 'erotica-adult', 'count': 1}
#  {'name': 'previous-submissions', 'count': 1}
#  {'name': 'to-read-p-s', 'count': 1} {'name': 'indie', 'count': 1}
#  {'name': 'fun', 'count': 1} {'name': 'mystery', 'count': 1}
#  {'name': 'danger', 'count': 1}
#  {'name': 'reviewed-books-2015', 'count': 1}
#  {'name': 'reviewed-books', 'count': 1}
#  {'name': 'psychology-romance', 'count': 1} {'name': 'earcs', 'count': 1}
#  {'name': 'dissociative-identity-disorder', 'count': 1}
#  {'name': 'june-2015', 'count': 1} {'name': 'tbr', 'count': 1}
#  {'name': 'sounds-interesting', 'count': 1}
#  {'name': 'favorites', 'count': 1}]
# [{'name': 'currently-reading', 'count': 30}
#  {'name': 'to-read', 'count': 6} {'name': 'mystery', 'count': 2}
#  {'name': 'next-in-series-to-read', 'count': 1}
#  {'name': 'murder', 'count': 1} {'name': 'missing-persons', 'count': 1}
#  {'name': 'gay', 'count': 1} {'name': 'cops', 'count': 1}
#  {'name': 'reading-challenge', 'count': 1}]
# [{'name': 'to-read', 'count': 50}
#  {'name': 'currently-reading', 'count': 12}
#  {'name': 'didn-t-finish', 'count': 1} {'name': 'kindle-book', 'count': 1}
#  {'name': 'ebooks-read', 'count': 1} {'name': 'tbr', 'count': 1}
#  {'name': 'shelf-c-authors', 'count': 1}
#  {'name': 'genre-mys-thrill-act', 'count': 1}
#  {'name': 'own-it', 'count': 1} {'name': 'free-friday', 'count': 1}
#  {'name': 'owned', 'count': 1} {'name': 'next-to-read', 'count': 1}
#  {'name': 'mysteries-and-thrillers', 'count': 1}
#  {'name': '2013-release', 'count': 1} {'name': 'un-read', 'count': 1}
#  {'name': 'thriller', 'count': 1} {'name': 'fall-15-16', 'count': 1}
#  {'name': 'adult', 'count': 1} {'name': 'waiting-on-my-nook', 'count': 1}
#  {'name': 'kindle-freebie', 'count': 1} {'name': 'own-kindle', 'count': 1}
#  {'name': 'no-interest-now', 'count': 1} {'name': 'own-ebook', 'count': 1}
#  {'name': 'amazon', 'count': 1} {'name': 'owned-kindle', 'count': 1}
#  {'name': 'kindle', 'count': 1} {'name': 'armchair-africa', 'count': 1}
#  {'name': 'ai-up-next-reads', 'count': 1}
#  {'name': 'a1-immediate-read', 'count': 1}
#  {'name': 'a1-i-own-books', 'count': 1}]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# -------------------------------------------------------------------
# 5. Rating Distributions
# -------------------------------------------------------------------
plt.figure(figsize=(6,4))
sns.histplot(df["average_rating"].dropna(), bins=20, kde=True)
plt.title("Distribution of Average Ratings")
plt.xlabel("Average Rating")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(6,4))
sns.histplot(df["ratings_count"].dropna(), bins=10)
plt.title("Distribution of Ratings Count")
plt.xlabel("Ratings Count")
plt.ylabel("Count")
plt.xscale("log")
plt.show()

# %%
# -------------------------------------------------------------------
# 6. Text length and missingness
# -------------------------------------------------------------------
if "description" in df.columns:
    df["desc_len"] = df["description"].fillna("").apply(lambda x: len(str(x).split()))
    sns.histplot(df["desc_len"], bins=30)
    plt.title("Distribution of Description Lengths (word count)")
    plt.show()

# Percentage of missing values
missing_pct = df.isna().mean().sort_values(ascending=False) * 100
plt.figure(figsize=(8,4))
sns.barplot(x=missing_pct, y=missing_pct.index)
plt.title("Missing Values (%) per Column")
plt.xlabel("Percent Missing")
plt.show()

# %%
from pathlib import Path
# -------------------------------------------------------------------
# 7. Save a local sample for offline dev/testing
# -------------------------------------------------------------------
Path("../raw").mkdir(parents=True, exist_ok=True)
out_path = "../raw/goodreads_sample.csv"
df.to_csv(out_path, index=False)
print(f"💾 Saved sample data to {out_path}")
# Out:
# 💾 Saved sample data to ../raw/goodreads_sample.csv
